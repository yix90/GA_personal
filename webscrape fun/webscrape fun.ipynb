# %% [markdown]
# # Webscrape fun

# %%
import pandas as pd
import urllib
import re
import requests as req
from bs4 import BeautifulSoup
import json

# %%
domain = 'www.runescape.com'
UserKey = '600075c5c13b41088891d10919abc493'  #ADD THIS ONE IN
url = 'https://api.similarweb.com/v1/website/{0}/category-rank/category-rank?api_key={1}'.format(domain, UserKey)

print url
# Out:
# https://api.similarweb.com/v1/website/www.runescape.com/category-rank/category-rank?api_key=600075c5c13b41088891d10919abc493

# %%
#Run once
jsun = urllib.urlopen(url).read()

# %%
print jsun
# Out:
# {"error":{"message":"Seems you're out of API calls. Please upgrade your account: https://developer.similarweb.com/pricing","code":403}}

# %% [markdown]
# ### I try youtube see how

# %%
url = 'http://youtu.be/PaghIdSJKvQ'
youhtml = urllib.urlopen(url).read()
print len(youhtml)
# Out:
# 184811
# <!DOCTYPE html><html lang="en" data-cast-api-enabled="true"><head><style name="www-roboto" >@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:local('Roboto Medium'),local('Roboto-Medium'),url(//fonts.gstatic.com/s/roboto/v18/RxZJdnzeo3R5zSexge8UUaCWcynf_cDxXwCLxiixG1c.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local('Roboto Regular'),local('Roboto-Regular'),url(//fonts.gstatic.com/s/roboto/v18/zN7GBFwfMP4uA6AR0HCoLQ.ttf)forma

# %%
yousoup = BeautifulSoup(youhtml, 'html.parser', from_encoding="utf-8")

# %%
re.match(r'<.+>(.*)\s-.*<.+>', str(yousoup.title)).group(1)
# Out:
# "How To Tell if You're a Basic Bitch"

# %%
type(yousoup.title)
# Out:
# bs4.element.Tag

# %%
def get_title_youtube(url):
    html = urllib.urlopen(url).read()
    soup = BeautifulSoup(html, 'html.parser', from_encoding="utf-8")
    title = re.match(r'<.+>(.*) - YouTube.*<.+>', str(soup.title)).group(1)
    return title

# %%
get_title_youtube('https://www.youtube.com/watch?v=uCdfze1etec')
# Out:
# "ESPN SportsCenter's Not Top Ten - 12-06-13"

# %%
#Vimeo

# %%
url = 'https://vimeo.com/252209946'
html = urllib.urlopen(url).read()
soupy = BeautifulSoup(html, 'html.parser', from_encoding="utf-8")
title_tag = soupy.h1
# Out:
# <h1 class="clip_info-header">Cautionary Tales</h1>

# %%
#Quora
url = 'https://www.quora.com/Whats-your-MBTI-personality-type'
html = urllib.urlopen(url).read()
soupy = BeautifulSoup(html, 'html.parser', from_encoding="utf-8")

# %%
for line in soupy.find_all(attrs={"class": "ui_qtext_para"}):
    print "".join(re.findall('>([^<]+)<',str(line)))
    print "__________________________________________________________________"
# Out:
# I did the 16personalities test, and before I tell you the results, allow me to note why this test should be given minimal consideration.
# __________________________________________________________________
# First of all, the questions were extremely ambiguous. Let’s look at the first two:
# __________________________________________________________________
# I don’t know about you, but these questions are ridiculously vague to be answered for me. With this in mind, I believe the results are as true as this month’s horoscope (and every other month’s.)
# __________________________________________________________________
# Furthermore, the results…
# __________________________________________________________________
# A few words and percentages to describe a personality? That’s not how it works. A human’s personality is a very intricate building which simply cannot be described in this straightforward way.
# __________________________________________________________________
# ...

# %%
url='http://wallpaperpassion.com/upload/23700/friendship-boy-and-girl-wallpaper.jpg'
request_html = req.get(url)
print request_html
# Out:
# <Response [404]>

# %%
request_html.status_code
# Out:
# 200

# %%
#Lets try Google images!
#Remember to get your credentials!

import io
import os

# Imports the Google Cloud client library
from google.cloud import vision
from google.cloud.vision import types

# Instantiates a client
client = vision.ImageAnnotatorClient(credentials="C:\Program1\My Project laalaaaaa-da9419d9edab.json")

# The name of the image file to annotate
file_name = os.path.join(
    os.path.dirname(__file__),
    'http://i817.photobucket.com/albums/zz96/kamioo/Deathgrip.png')

# Loads the image into memory
with io.open(file_name, 'rb') as image_file:
    content = image_file.read()

image = types.Image(content=content)

# Performs label detection on the image file
response = client.label_detection(image=image)
labels = response.label_annotations

print('Labels:')
for label in labels:
    print(label.description)
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# <ipython-input-3-bcd1d4d36047> in <module>()
#      10
#      11 # Instantiates a client
# ---> 12 client = vision.ImageAnnotatorClient()
#      13
#      14 # The name of the image file to annotate
#
# C:\Users\User\Anaconda2\lib\site-packages\google\cloud\vision_v1\gapic\image_annotator_client.pyc in __init__(self, channel, credentials, client_config, client_info)
#      94                 self.SERVICE_ADDRESS,
#      95                 credentials=credentials,
# ---> 96                 scopes=self._DEFAULT_SCOPES)
#      97
#      98         self.image_annotator_stub = (
#
# C:\Users\User\Anaconda2\lib\site-packages\google\api_core\grpc_helpers.pyc in create_channel(target, credentials, scopes, **kwargs)
#     130     """
#     131     if credentials is None:
# ...
