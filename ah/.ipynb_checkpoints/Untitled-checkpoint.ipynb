# %% [markdown]
# Japan death rate - Hokkaido

# %%
import pandas as pd
import numpy as np

# %%
ahh = pd.read_csv('./nj01k0001.csv', encoding='shift_jisx0213')

# %%
ahh.head(20)
# Out:
#                                                 平成27年 人口動態調査 Unnamed: 2  \
# 0   保管統計表　都道府県編　死亡∓死因　第１表−０１（北海道）　死亡数，性・死因(死因基本分類)...    NaN        NaN
# 1                                                 NaN      男          女
# 2                                             ０１　北海道　    NaN        NaN
# 3                                                総　　数  31391      29276
# 4                                                第１章　    571        602
# 5                                           (A00-A09)     34         55
# 6                                              A00　　　      -          -
# 7                                             A00.0　　      -          -
# 8                                             A00.1　　      -          -
# 9                                             A00.9　　      -          -
# 10                                             A01　　　      -          -
# 11                                            A01.0　　      -          -
# ...

# %%
ahh.shape
# Out:
# (13612, 4)

# %%
ahh.dropna(axis=1, how='all')
# Out:
#                                                    平成27年 人口動態調査 Unnamed: 2
# 0      保管統計表　都道府県編　死亡∓死因　第１表−０１（北海道）　死亡数，性・死因(死因基本分類)...    NaN        NaN
# 1                                                    NaN      男          女
# 2                                                ０１　北海道　    NaN        NaN
# 3                                                   総　　数  31391      29276
# 4                                                   第１章　    571        602
# 5                                              (A00-A09)     34         55
# 6                                                 A00　　　      -          -
# 7                                                A00.0　　      -          -
# 8                                                A00.1　　      -          -
# 9                                                A00.9　　      -          -
# 10                                                A01　　　      -          -
# ...
