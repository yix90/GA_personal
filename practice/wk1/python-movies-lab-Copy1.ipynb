# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# ## Python Review with Movie Data
#
# _Author: Kiefer Katovich and Dave Yerrington | DSI-SF_
#
# ---
#
# In this lab you'll be using the provided imdb `movies` list below as your dataset.
#
# This lab is designed to practice iteration and funcitons in particular. The normal questions are more gentle, and the challenge questions are suitable for advanced/expert python or programming-experienced students.
#
# All the questions require writing functions and also use iteration to solve. You should print out a test of each function you write.
#
#
# ### 1. Load the provided list of movies dictionaries.

# %%
# List of movies dictionaries:

movies = [
{
"name": "Usual Suspects", 
"imdb": 7.0,
"category": "Thriller"
},
{
"name": "Hitman",
"imdb": 6.3,
"category": "Action"
},
{
"name": "Dark Knight",
"imdb": 9.0,
"category": "Adventure"
},
{
"name": "The Help",
"imdb": 8.0,
"category": "Drama"
},
{
"name": "The Choice",
"imdb": 6.2,
"category": "Romance"
},
{
"name": "Colonia",
"imdb": 7.4,
"category": "Romance"
},
{
"name": "Love",
"imdb": 6.0,
"category": "Romance"
},
{
"name": "Bride Wars",
"imdb": 5.4,
"category": "Romance"
},
{
"name": "AlphaJet",
"imdb": 3.2,
"category": "War"
},
{
"name": "Ringing Crime",
"imdb": 4.0,
"category": "Crime"
},
{
"name": "Joking muck",
"imdb": 7.2,
"category": "Comedy"
},
{
"name": "What is the name",
"imdb": 9.2,
"category": "Suspense"
},
{
"name": "Detective",
"imdb": 7.0,
"category": "Suspense"
},
{
"name": "Exam",
"imdb": 4.2,
"category": "Thriller"
},
{
"name": "We Two",
"imdb": 7.2,
"category": "Romance"
}
]

# %% [markdown]
# ---
#
# ### 2. Filtering data by IMDB score
#
# #### 2.1
#
# Write a function that:
#
# 1. Accepts a single movie dictionary from the `movies` list as an argument.
# 2. Returns True if the IMDB score is above 5.5.
#
# #### 2.2 [Challenge]
#
# Write a function that:
#
# 1. Accepts the movies list and a specified category.
# 2. Returns True if the average score of the category is higher than the average score of all movies.

# %%
import numpy as np
def movie_rat(movie):
    if movie["imdb"]>5.5:
        return True
    else:
        return False

#oops I coded this wrongly
def movie_cat(movie, cat="Suspense"):
    mov_list = ["Thriller", "Action", "Adventure", "Drama", "Romance", "War", "Crime", "Comedy", "Suspense"]
    all_score = []
    mov_score = []
    for mov_d in mov_list:
        score = []
        for mov in movie:
            all_score.append(mov["imdb"])
            if mov["category"] == mov_d:
                score.append(mov["imdb"])
        mov_score.append(np.mean(score))
    avg_score = sum(all_score)/len(all_score)
    if mov_score[mov_list.index(cat)] > avg_score:
        return True
    else:
        return False
# Out:
# 6.48666666667
# 8.0
# True

# %% [markdown]
# ---
#
# ### 3. Creating subsets by numeric condition
#
# #### 3.1
#
# Write a function that:
#
# 1. Accepts the list of movies and a specified imdb score.
# 2. Returns the sublist of movies that have a score greater than the specified score.
#
# #### 3.2 [Expert]
#
# Write a function that:
#
# 1. Accepts the movies list as an argument.
# 2. Returns the movies list sorted first by category and then by movie according to average score and individual score, respectively.

# %%
import operator
def mov_score(movies, sc=5.0):
    mov_list=[]
    for mov in movies:
        if mov["imdb"] > sc:
            mov_list.append(mov)
    return mov_list

#So the Expert part wants us to sort the genres according to average score, not to append it inside -_-

def mov_score_ad(movie):
    cat_list = ["Thriller", "Action", "Adventure", "Drama", "Romance", "War", "Crime", "Comedy", "Suspense"]
    mov_list=[]
    index=0
    mov_score = []
    for mov_d in cat_list:
        score = []
        mov_temp = []
        for mov in movie:
            if mov["category"] == mov_d:
                score.append(mov["imdb"])
        mov_score.append(round(np.mean(score),2))
        for mov in movie:
            if mov["category"] == mov_d:
                mov["average"] = mov_score[index]
                mov_temp.append(mov)
        mov_temp.sort(key=operator.itemgetter('imdb'))
        mov_list.extend(mov_temp)
        index += 1
    return mov_list
mov_score_ad(movies)
# Out:
# [{'average': 5.6, 'category': 'Thriller', 'imdb': 4.2, 'name': 'Exam'},
#  {'average': 5.6,
#   'category': 'Thriller',
#   'imdb': 7.0,
#   'name': 'Usual Suspects'},
#  {'average': 6.3, 'category': 'Action', 'imdb': 6.3, 'name': 'Hitman'},
#  {'average': 9.0, 'category': 'Adventure', 'imdb': 9.0, 'name': 'Dark Knight'},
#  {'average': 8.0, 'category': 'Drama', 'imdb': 8.0, 'name': 'The Help'},
#  {'average': 6.44, 'category': 'Romance', 'imdb': 5.4, 'name': 'Bride Wars'},
#  {'average': 6.44, 'category': 'Romance', 'imdb': 6.0, 'name': 'Love'},
#  {'average': 6.44, 'category': 'Romance', 'imdb': 6.2, 'name': 'The Choice'},
#  {'average': 6.44, 'category': 'Romance', 'imdb': 7.2, 'name': 'We Two'},
#  {'average': 6.44, 'category': 'Romance', 'imdb': 7.4, 'name': 'Colonia'},
#  {'average': 3.2, 'category': 'War', 'imdb': 3.2, 'name': 'AlphaJet'},
#  {'average': 4.0, 'category': 'Crime', 'imdb': 4.0, 'name': 'Ringing Crime'},
#  {'average': 7.2, 'category': 'Comedy', 'imdb': 7.2, 'name': 'Joking muck'},
#  {'average': 8.1, 'category': 'Suspense', 'imdb': 7.0, 'name': 'Detective'},
#  {'average': 8.1,
#   'category': 'Suspense',
#   'imdb': 9.2,
#   'name': 'What is the name'}]

# %% [markdown]
# ---
#
# ### 4. Creating subsets by string condition
#
# #### 4.1
#
# Write a function that:
#
# 1. Accepts the movies list and a category name.
# 2. Returns the movie names within that category (case-insensitive!)
# 3. If the category is not in the data, print a message that it does not exist and return None.
#
# Recall that to convert a string to lowercase, you can use:
#
# ```python
# mystring = 'Dumb and Dumber'
# lowercase_mystring = mystring.lower()
# print lowercase_mystring
# 'dumb and dumber'
# ```
#
# #### 4.2 [Challenge]
#
# Write a function that:
#
# 1. Accepts the movies list and a "search string".
# 2. Returns a dictionary with keys `'category'` and `'title'` whose values are lists of categories that contain the search string and titles that contain the search string, respectively (case-insensitive!)

# %%
def movie_cat(movie, cat):
    mov_list = []
    for mov in movie:
        if cat.lower() == mov["category"].lower():
            mov_list.append(mov)
            counter += 1
    if len(mov_list) == 0:
        print "The category does not exist."
        return None
    else:
        return mov_list

import re
def movie_search(movie, string):
    mov_list=[]
    cat_list=[]
    stringl = string.lower()
    for mov in movie:
        acorn = re.search(stringl, mov["name"].lower())
        bcorn = re.search(stringl, mov["category"].lower())
        if acorn != None:
            if mov["name"] in mov_list:
                continue
            else:
                mov_list.append(mov["name"])
        if bcorn != None:
            if mov["category"] in cat_list:
                continue
            else:
                cat_list.append(mov["category"])
    mov_dict = {"title":mov_list, "category":cat_list}
    return mov_dict

movie_search(movies, 'lo')
# Out:
# {'category': [], 'title': ['Colonia', 'Love']}

# %% [markdown]
# ---
#
# ### 5. Multiple conditions
#
# #### 5.1
#
# Write a function that:
#
# 1. Accepts the movies list and a "search criteria" variable.
# 2. If the criteria variable is numeric, return a list of movie titles with a score greater than or equal to the criteria.
# 3. If the criteria variable is a string, return a list of movie titles that match that category (case-insensitive!). If there is no match, return an empty list and print an informative message.
#
# #### 5.2 [Expert]
#
# Write a function that:
#
# 1. Accepts the movies list and a string search criteria variable.
# 2. The search criteria variable can contain within it:
#   - Boolean operations: `'AND'`, `'OR'`, and `'NOT'` (can have/be lowercase as well, I just capitalized for clarity).
#   - Search criteria specified with syntax `score=...`, `category=...`, and/or `title=...`, where the `...` indicates what to look for.
#     - If `score` is present, it means scores greater than or equal to the value.
#     - For `category` and `title`, the string indicates that the category or title must _contain_ the search string (case-insensitive).
# 3. Return the matches for the search criteria specified.

# %%
def movie_search_ad1(movie, search):
    mov_list = []
    if isinstance(search, int) == True or isinstance(search, float) == True:
        for mov in movie:
            if mov["imdb"] >= search:
                mov_list.append(mov["name"])
        return mov_list
    elif isinstance(search, str) == True:
        stringl = search.lower()
        for mov in movie:
            bcorn = re.search(stringl, mov["category"].lower())
            if bcorn != None:
                mov_list.append(mov["name"])
        if len(mov_list) == 0:
            print "Keyword does not match."
            return None
        else:
            return mov_list
    else:
        return None

def movie_search_ad2(movie, search):
    search = search.lower()
    if 'and' in search:
        search.replace('and', and)
# Out:
# Keyword does not match.
