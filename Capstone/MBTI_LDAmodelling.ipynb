# %% [markdown]
# # OH FINALLY

# %% [markdown]
# Do you remember the bunch of youtube titles that I have gathered in the first notebook? Well...I haven't!
#
# I also haven't forgotten about the fact that I haven't modeled out the imagery plus the website categorization hahahah
#
# Do I have time for this? I dunnooo...
